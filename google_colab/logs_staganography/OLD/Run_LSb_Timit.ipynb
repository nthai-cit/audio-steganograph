# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
PROJECT_PATH = '/content/drive/MyDrive/Git-audio-stego/audio-steganograph/AudioStego/exp'

if os.path.exists(PROJECT_PATH):
    os.chdir(PROJECT_PATH)
    # !pip install -q librosa soundfile tensorflow scikit-learn seaborn
else:
    print(f" Không tìm thấy thư mục tại {PROJECT_PATH}")

# %%
# !python run_case_limited.py \
  --case_id 5 \
  --input_dir "/content/drive/MyDrive/HK2-20252026/data/timit" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.5" \
  --target_rate 0.5 \
  --max_files 1000
# Out:
# [*] Chế độ tạo Dataset CNN | Case: 5_Random_Adaptive_ContentSalt
# [*] Thư mục Logs: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.5/logs
# [1000/1000] Done: 6_data_TEST_DR5_FHES0_SX389.WAV.wav | PSNR: 96.47
# [DONE] Kết quả tại: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.5

# %%
# !python run_case_limited.py \
  --case_id 5 \
  --input_dir "/content/drive/MyDrive/HK2-20252026/data/timit" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.065" \
  --target_rate 0.065 \
  --max_files 1000
# Out:
# [*] Chế độ tạo Dataset CNN | Case: 5_Random_Adaptive_ContentSalt
# [*] Thư mục Logs: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.065/logs
# [1000/1000] Done: 6_data_TEST_DR5_FHES0_SX389.WAV.wav | PSNR: 105.29
# [DONE] Kết quả tại: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.065

# %%
# !python run_case_limited.py \
  --case_id 5 \
  --input_dir "/content/drive/MyDrive/HK2-20252026/data/timit" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.1" \
  --target_rate 0.1 \
  --max_files 1000
# Out:
# [*] Chế độ tạo Dataset CNN | Case: 5_Random_Adaptive_ContentSalt
# [*] Thư mục Logs: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.1/logs
# [1000/1000] Done: 6_data_TEST_DR5_FHES0_SX389.WAV.wav | PSNR: 103.32
# [DONE] Kết quả tại: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.1

# %%
# !python run_case_limited.py \
  --case_id 5 \
  --input_dir "/content/drive/MyDrive/HK2-20252026/data/timit" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.2" \
  --target_rate 0.2 \
  --max_files 1000
# Out:
# [*] Chế độ tạo Dataset CNN | Case: 5_Random_Adaptive_ContentSalt
# [*] Thư mục Logs: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.2/logs
# [1000/1000] Done: 6_data_TEST_DR5_FHES0_SX389.WAV.wav | PSNR: 100.43
# [DONE] Kết quả tại: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.2

# %%
# !python run_case_limited.py \
  --case_id 5 \
  --input_dir "/content/drive/MyDrive/HK2-20252026/data/timit" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.3" \
  --target_rate 0.3 \
  --max_files 1000
# Out:
# [*] Chế độ tạo Dataset CNN | Case: 5_Random_Adaptive_ContentSalt
# [*] Thư mục Logs: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.3/logs
# [1000/1000] Done: 6_data_TEST_DR5_FHES0_SX389.WAV.wav | PSNR: 98.63
# [DONE] Kết quả tại: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.3

# %%
# !python run_case_limited.py \
  --case_id 5 \
  --input_dir "/content/drive/MyDrive/HK2-20252026/data/timit" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4" \
  --target_rate 0.4 \
  --max_files 1000
# Out:
# [*] Chế độ tạo Dataset CNN | Case: 5_Random_Adaptive_ContentSalt
# [*] Thư mục Logs: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4/logs
# [1000/1000] Done: 6_data_TEST_DR5_FHES0_SX389.WAV.wav | PSNR: 97.48
# [DONE] Kết quả tại: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4

# %%
# !python run_case_limited.py \
  --case_id 5 \
  --input_dir "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4/cover" \
  --secret_dir "/content/drive/MyDrive/HK2-20252026/data/pascal-voc-2012" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500" \
  --limit 500 \
  --max_files 1000 \
  --size 256
# Out:
# [*] Scanning Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4/cover...
# [*] Scanning Secret: /content/drive/MyDrive/HK2-20252026/data/pascal-voc-2012...
# --------------------------------------------------
# [*] Mode: DATASET GENERATION (VN Time)
# [*] Cover: 1000 | Secret Pool: 500
# [*] Image Size Target: 256x256
# --------------------------------------------------
# [1000/1000] 6_data_TEST_DR4_FDMS0_SI1218.WAV.wav -> OK (88.60dB | 2.24 kBps)
# [DONE] Finished.
# Structure: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500/5_Random_Adaptive_ContentSalt_20260201_080450/[logs, cover, stego]
# Total: 1000 | Created: 999 | Skipped: 1

# %%
# !python run_case_limited.py \
  --case_id 5 \
  --input_dir "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4/cover" \
  --secret_dir "/content/drive/MyDrive/HK2-20252026/data/pascal-voc-2012" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500" \
  --limit 500 \
  --max_files 1000 \
  --size 124
# Out:
# [*] Scanning Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4/cover...
# [*] Scanning Secret: /content/drive/MyDrive/HK2-20252026/data/pascal-voc-2012...

# %%
# !python run_case_limited.py \
  --case_id 5 \
  --input_dir "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4/cover" \
  --secret_dir "/content/drive/MyDrive/HK2-20252026/data/pascal-voc-2012" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_512" \
  --limit 500 \
  --max_files 1000 \
  --size 512
# Out:
# [*] Scanning Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4/cover...
# [*] Scanning Secret: /content/drive/MyDrive/HK2-20252026/data/pascal-voc-2012...
# --------------------------------------------------
# [*] Mode: DATASET GENERATION (VN Time)
# [*] Cover: 1000 | Secret Pool: 500
# [*] Image Size Target: 512x512
# --------------------------------------------------
# [1000/1000] 6_data_TEST_DR4_MGMM0_SI1129.WAV.wav -> OK (87.92dB | 2.61 kBps)
# [DONE] Finished.
# Structure: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_512/5_Random_Adaptive_ContentSalt_20260201_083210/[logs, cover, stego]
# Total: 1000 | Created: 993 | Skipped: 7
