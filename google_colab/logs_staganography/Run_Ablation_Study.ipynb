# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# Đường dẫn nguồn trên Drive
DRIVE_SRC = "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train"

print(f" Đang kiểm tra số lượng file tại: {DRIVE_SRC}")

count = 0
for root, dirs, files in os.walk(DRIVE_SRC):
    wav_files = [f for f in files if f.endswith('.wav')]
    count += len(wav_files)
    if count > 0 and count % 100 == 0:
        print(f"   ... Đã tìm thấy {count} file...")

print(f" TỔNG KẾT: Colab nhìn thấy {count} file .wav trên Drive.")

if count < 10:
    print(" CẢNH BÁO: Drive chưa hiển thị đủ file..")
# Out:
#  Đang kiểm tra số lượng file tại: /content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train
#  TỔNG KẾT: Colab nhìn thấy 750 file .wav trên Drive.

# %%
# !mkdir -p "/content/local_input"
# !mkdir -p "/content/local_output"


# !cp -r -n -v "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train/." "/content/local_input/"

# !cp "/content/drive/MyDrive/HK1-20252026/Steganography/Data/audio-cats-and-dogs/5/cat_24.wav" "/content/local_secret.wav"

import os
local_count = sum([len(files) for r, d, files in os.walk("/content/local_input")])
print(f"\n Đã copy xuống máy ảo: {local_count} file.")
# Out:
#  Đã copy xuống máy ảo: 0 file.

# %%
import numpy as np
import os
PROJECT_PATH = '/content/drive/MyDrive/Git-audio-stego/audio-steganograph/AudioStego/exp'

if os.path.exists(PROJECT_PATH):
    os.chdir(PROJECT_PATH)
    # !pip install -q librosa soundfile tensorflow scikit-learn seaborn
else:
    print(f" Không tìm thấy thư mục tại {PROJECT_PATH}")

# %%
# !python run_case.py \
  --case_id 4 \
  --password "NguyenNgocChien" \
  --input_dir "/content/local_input" \
  --secret_file "/content/local_secret.wav" \
  --output_base "/content/local_output"
# Out:
# [*] Case: 4_Random_Adaptive_DefaultSalt | Input: local_input
# [*] Secret: /content/local_secret.wav
# [*] No Save Mode: OFF
# [*] Found: 750 files
# [750/750] Zeno - Signs_vocals.wav -> PSNR:107.4dB | CPU:85.6% | RAM:56.3MB
# [DONE] Hoàn tất. Log tại: logs/benchmark_local_input_4_Random_Adaptive_DefaultSalt_20260611_013538.csv

# %%
# !rm -rf "/content/local_output"
# !mkdir -p "/content/local_output"
print("Đã xóa và tạo lại thư mục output rỗng.")
# Out:
# Đã xóa và tạo lại thư mục output rỗng.

# %%
# !python run_case.py \
  --case_id 1 \
  --k 1 \
  --password "NguyenNgocChien" \
  --input_dir "/content/local_input" \
  --secret_file "/content/local_secret.wav" \
  --output_base "/content/local_output"

  # Xóa sạch thư mục output
# !rm -rf "/content/local_output"

# !mkdir -p "/content/local_output"
print("Đã xóa và tạo lại thư mục output rỗng.")
# Out:
# [*] Case: 1_NoRandom | Input: local_input
# [*] Secret: /content/local_secret.wav
# [*] No Save Mode: OFF
# [*] Found: 750 files
# [110/750] BigTroubles - Phantom_vocals.wav -> PSNR:105.3dB | CPU:31.3% | RAM:53.1MBobject address  : 0x79cee3881fc0
# object refcount : 3
# object type     : 0xa284e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C
# ^C
# Đã xóa và tạo lại thư mục output rỗng.

# %%
# !python run_case.py \
  --case_id 3 \
  --k 1 \
  --password "NguyenNgocChien" \
  --input_dir "/content/local_input" \
  --secret_file "/content/local_secret.wav" \
  --output_base "/content/local_output"

  # Xóa sạch thư mục output
# !rm -rf "/content/local_output"

# (Tùy chọn) Kiểm tra xem đã xóa chưa và tạo lại thư mục rỗng cho lần chạy sau
# !mkdir -p "/content/local_output"
print("Đã xóa và tạo lại thư mục output rỗng.")
# Out:
# [*] Case: 3_Random_Fixed_ContentSalt | Input: local_input
# [*] Secret: /content/local_secret.wav
# [*] No Save Mode: OFF
# [*] Found: 750 files
# [750/750] Zeno - Signs_vocals.wav -> PSNR:107.4dB | CPU:82.3% | RAM:55.8MB
# [DONE] Hoàn tất. Log tại: logs/benchmark_local_input_3_Random_Fixed_ContentSalt_20260610_192014.csv
# Đã xóa và tạo lại thư mục output rỗng.

# %%
# !python run_case.py \
  --case_id 4 \
  --password "NguyenNgocChien" \
  --input_dir "/content/local_input" \
  --secret_file "/content/local_secret.wav" \
  --output_base "/content/local_output"

  # Xóa sạch thư mục output
# !rm -rf "/content/local_output"

# (Tùy chọn) Kiểm tra xem đã xóa chưa và tạo lại thư mục rỗng cho lần chạy sau
# !mkdir -p "/content/local_output"
print("Đã xóa và tạo lại thư mục output rỗng.")
# Out:
# [*] Case: 4_Random_Adaptive_DefaultSalt | Input: local_input
# [*] Secret: /content/local_secret.wav
# [*] No Save Mode: OFF
# [*] Found: 750 files
# [750/750] Zeno - Signs_vocals.wav -> PSNR:107.4dB | CPU:87.6% | RAM:53.2MB
# [DONE] Hoàn tất. Log tại: logs/benchmark_local_input_4_Random_Adaptive_DefaultSalt_20260203_190216.csv
# Đã xóa và tạo lại thư mục output rỗng.

# %%
# !python run_case.py \
  --case_id 5 \
  --password "NguyenNgocChien" \
  --input_dir "/content/local_input" \
  --secret_file "/content/local_secret.wav" \
  --output_base "/content/local_output"
# Out:
# [*] Case: 5_Random_Adaptive_ContentSalt | Input: local_input
# [*] Secret: /content/local_secret.wav
# [*] No Save Mode: OFF
# [*] Found: 750 files
# [750/750] Zeno - Signs_vocals.wav -> PSNR:107.4dB | CPU:84.9% | RAM:53.3MB
# [DONE] Hoàn tất. Log tại: logs/benchmark_local_input_5_Random_Adaptive_ContentSalt_20260205_094114.csv

# %%
# !python run_case.py \
  --case_id 7 \
  --input_dir "/content/local_input" \
  --secret_file "/content/local_secret.wav" \
  --output_base "/content/local_output"
# Out:
# [*] Case: 7_PhaseCoding | Input: local_input
# [*] Secret: /content/local_secret.wav
# [*] No Save Mode: OFF
# [*] Found: 750 files
# [750/750] Zeno - Signs_vocals.wav -> PSNR:25.8dB | CPU:85.4% | RAM:51.6MB
# [DONE] Hoàn tất. Log tại: logs/benchmark_local_input_7_PhaseCoding_20260203_210739.csv
# Đã xóa và tạo lại thư mục output rỗng.

# %%
import os
import shutil
import time


SOURCE_DIR = "/content/local_output/4_Random_Adaptive_DefaultSalt"
# Đường dẫn đích trên Drive (giữ nguyên cấu trúc thư mục)
DEST_DIR = "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/4_Random_Adaptive_DefaultSalt"

print(f" BẮT ĐẦU COPY TỪNG FILE...\nNguồn: {SOURCE_DIR}\nĐích:  {DEST_DIR}")

# Tạo thư mục đích trên Drive
os.makedirs(DEST_DIR, exist_ok=True)

# Lấy danh sách file cần copy
files_to_copy = [f for f in os.listdir(SOURCE_DIR) if f.endswith('.wav') or f.endswith('.csv')]
total_files = len(files_to_copy)
copied_count = 0

start_time = time.time()

for i, filename in enumerate(files_to_copy):
    src_file = os.path.join(SOURCE_DIR, filename)
    dest_file = os.path.join(DEST_DIR, filename)

    # Kiểm tra nếu file đã tồn tại trên Drive với cùng kích thước -> Bỏ qua
    if os.path.exists(dest_file):
        if os.path.getsize(src_file) == os.path.getsize(dest_file):
            print(f"[{i+1}/{total_files}] ⏭ Bỏ qua (Đã có): {filename}")
            copied_count += 1
            continue

    try:
        # Copy file
        shutil.copy2(src_file, dest_file)
        print(f"[{i+1}/{total_files}]  Đã copy: {filename}")
        copied_count += 1

        # Flush bộ nhớ đệm xuống đĩa để đảm bảo file được ghi thật sự
        if (i + 1) % 10 == 0:
            os.sync()

    except OSError as e:
        if e.errno == 28: # Lỗi hết dung lượng
            print(f"\n DỪNG LẠI: Google Drive ĐÃ HẾT DUNG LƯỢNG (Full) tại file thứ {i+1}.")
            print(f"File gây lỗi: {filename}")
            print(f"Kích thước file này: {os.path.getsize(src_file) / (1024*1024):.2f} MB")
            break
        else:
            print(f"\n Lỗi khi copy file {filename}: {e}")

print(f"\n KẾT THÚC QUÁ TRÌNH.")
print(f"Tổng số file đã xử lý: {copied_count}/{total_files}")
print(f"Thời gian chạy: {time.time() - start_time:.2f} giây")

# %%
import os

# Đường dẫn thư mục trên Drive cần kiểm tra
target_dir = "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/3_Random_Fixed_ContentSalt"

print(f"Đang kiểm tra thư mục: {target_dir}")

if os.path.exists(target_dir):
    # Lấy danh sách tất cả file .wav
    files = [f for f in os.listdir(target_dir) if f.endswith('.wav')]
    count = len(files)

    print(f"Tổng số file .wav hiện có: {count}")

    if count >= 750:
        print("Đã đủ 750 file.")
    else:
        print(f"Chưa đủ. Còn thiếu: {750 - count} file.")
else:
    print("Thư mục chưa được tạo hoặc đường dẫn sai.")
# Out:
# Đang kiểm tra thư mục: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/3_Random_Fixed_ContentSalt
# Tổng số file .wav hiện có: 750
# Đã đủ 750 file.

# %%
# !python run_case.py \
  --case_id 1 \
  --input_dir "/content/local_input" \
  --secret_file "/content/local_secret.wav" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation"
# Out:
# [*] Case: 1_NoRandom | Input: local_input
# [*] Secret File: /content/local_secret.wav
# [*] Log path: logs/benchmark_local_input_1_NoRandom_20260201_040937.csv
# [*] Found: 750 files
# [750/750] Zeno - Signs_vocals.wav -> PSNR: 107.36 dB
# [DONE] Hoàn tất. Log tại: logs/benchmark_local_input_1_NoRandom_20260201_040937.csv

# %%
# !python run_case.py \
  --case_id 7 \
  --input_dir "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train" \
  --secret_file "/content/local_secret.wav" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation"
# Out:
# [*] Case: 7_PhaseCoding | Input: train
# [*] Secret: /content/local_secret.wav
# [*] No Save Mode: OFF
# [*] Found: 750 files
# [750/750] Zeno - Signs_vocals.wav -> PSNR:25.8dB | CPU:64.7% | RAM:55.0MB
# [DONE] Hoàn tất. Log tại: logs/benchmark_train_7_PhaseCoding_20260612_120853.csv

# %%
# !python run_case.py \
  --case_id 3 \
  --input_dir "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train" \
  --secret_file "/content/local_secret.wav" \
  --output_base "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/k_4" \
  --k 4
# Out:
# python3: can't open file '/content/run_case.py': [Errno 2] No such file or directory
