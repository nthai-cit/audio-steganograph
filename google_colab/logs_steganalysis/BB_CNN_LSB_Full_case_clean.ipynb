# %%
import os
from google.colab import drive

drive.mount('/content/drive')

PROJECT_PATH = '/content/drive/MyDrive/Git-audio-stego/audio-steganograph'
if os.path.exists(PROJECT_PATH):
    os.chdir(PROJECT_PATH)
    print(" Working dir:", os.getcwd())
else:
    raise FileNotFoundError(f"Không tìm thấy project tại {PROJECT_PATH}")
# Out:
# Mounted at /content/drive
#  Working dir: /content/drive/.shortcut-targets-by-id/1SvhC4GWaz_W1MIeiJTeqYmEFf-sAyn2J/Git-audio-stego/audio-steganograph

# %%
# COVER_DIR  = "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq"
# BASE_STEGO = "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation"
# BASE_CACHE = "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data"
# BASE_LOG   = "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs"

# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train" \
  --algo cnn \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/2_Random_Fixed_DefaultSalt" \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_2_Random_Fixed_DefaultSalt" \
  --log_dir   "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_LSB_2_Random_Fixed_DefaultSalt" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-06-11 04:53:58.719858: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-11 04:54:03
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/2_Random_Fixed_DefaultSalt
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# [Log] Base Directory: /content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_LSB_2_Random_Fixed_DefaultSalt/CNN_D5_F64_LR0.0001_20260611-115403
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train" \
  --algo cnn \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/3_Random_Fixed_ContentSalt" \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_3_Random_Fixed_ContentSalt" \
  --log_dir   "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_LSB_3_Random_Fixed_ContentSalt" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001 \
  --runs 2
# Out:
# 2026-06-11 07:54:05.834722: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-11 07:54:08
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/3_Random_Fixed_ContentSalt
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# [Log] Base Directory: /content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_LSB_3_Random_Fixed_ContentSalt/CNN_D5_F64_LR0.0001_20260611-145408
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train" \
  --algo cnn \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/4_Random_Adaptive_DefaultSalt" \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_4_Random_Adaptive_DefaultSalt" \
  --log_dir   "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_LSB_4_Random_Adaptive_DefaultSalt" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001 \
  --runs 10
# Out:
# 2026-06-11 09:01:22.794352: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-11 09:01:27
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/4_Random_Adaptive_DefaultSalt
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train" \
  --algo cnn \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/5_Random_Adaptive_ContentSalt" \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_5_Random_Adaptive_ContentSalt" \
  --log_dir   "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_LSB5_Random_Adaptive_ContentSalt" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001 \
  --runs 10
# Out:
# 2026-06-14 09:57:06.759324: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-14 09:57:11
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/5_Random_Adaptive_ContentSalt
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train" \
  --algo cnn \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/1_NoRandom" \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_1_NoRandom" \
  --log_dir   "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_LSB_1_NoRandom_BILSTM" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001 \
  --use_bilstm \
  --runs 5
# Out:
# 2026-06-14 08:41:33.823394: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-14 08:41:36
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/1_NoRandom
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: True
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# [Log] Base Directory: /content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_LSB_1_NoRandom_BILSTM/CNN_D5_F64_LR0.0001_20260614-154136
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train" \
  --algo cnn \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/5_Random_Adaptive_ContentSalt" \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_5_Random_Adaptive_ContentSalt" \
  --log_dir   "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_LSB5_Random_Adaptive_ContentSalt" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001 \
  --runs 10
# Out:
# 2026-06-14 06:27:12.350311: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-14 06:27:15
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/5_Random_Adaptive_ContentSalt
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train" \
  --algo cnn \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/7_PhaseCoding" \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/CNN_7_PhaseCoding" \
  --log_dir   "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_CNN_7_PhaseCoding" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001 \
  --runs 10
# Out:
# 2026-06-12 17:34:52.696025: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-12 17:34:56
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Data/musdb18-hq/train
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/7_PhaseCoding
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# [Log] Base Directory: /content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_CNN_7_PhaseCoding/CNN_D5_F64_LR0.0001_20260613-003456
# ...

# %%
# !python train.py \
  --cover "" \
  --algo cnn \
  --stego "" \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/MUSDB_Alarood2022_CNN" \
  --log_dir   "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_Alarood2022_CNN" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001 \
  --runs 10
# Out:
# 2026-06-14 07:32:35.248945: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-14 07:32:41
# ...
#  Dữ liệu Cover:
#  Dữ liệu Stego:
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# [Log] Base Directory: /content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/MUSDB_Alarood2022_CNN/CNN_D5_F64_LR0.0001_20260614-143241
# [Data] Loading data (CNN)...
# [Cache] Found cache file: /content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/MUSDB_Alarood2022_CNN/features_cnn.npz
#
# ...
