# %%
import os
import shutil
from google.colab import drive
# Kết nối lại (ép buộc)
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
PROJECT_PATH = '/content/drive/MyDrive/Git-audio-stego/audio-steganograph'
if os.path.exists(PROJECT_PATH):
    os.chdir(PROJECT_PATH)
    # !pip install -q librosa soundfile tensorflow scikit-learn seaborn
else:
    print(f" Không tìm thấy thư mục tại {PROJECT_PATH}")


print("\n có thể bắt đầu Train.")

import numpy as np
import os
# Out:
#  có thể bắt đầu Train.

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/004-Timit_voc_500_256/5_Random_Adaptive_ContentSalt_20260619_193847/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/004-Timit_voc_500_256/5_Random_Adaptive_ContentSalt_20260619_193847//stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/CNN_M5_Timit1000_voc500_256_7dot6kbps" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/CNN_M5_Timit1000_voc500_256_7dot6kbps" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-06-19 13:34:16.150526: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-19 13:34:19
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/004-Timit_voc_500_256/5_Random_Adaptive_ContentSalt_20260619_193847/cover
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/004-Timit_voc_500_256/5_Random_Adaptive_ContentSalt_20260619_193847//stego
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/004-Timit_voc_500_128/5_Random_Adaptive_ContentSalt_20260619_213230/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/004-Timit_voc_500_128/5_Random_Adaptive_ContentSalt_20260619_213230/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/CNN_M5_Timit1000_voc500_128_7dot6kbps" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/CNN_M5_Timit1000_voc500_128_7dot6kbps" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-06-19 15:04:08.586268: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-19 15:04:12
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/004-Timit_voc_500_128/5_Random_Adaptive_ContentSalt_20260619_213230/cover
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/004-Timit_voc_500_128/5_Random_Adaptive_ContentSalt_20260619_213230/stego
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_256/5_Random_Adaptive_ContentSalt_20260201_080450/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_256/5_Random_Adaptive_ContentSalt_20260201_080450/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_voc500_256" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_voc500_256" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-06-13 07:37:01.554779: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-13 07:37:07
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_256/5_Random_Adaptive_ContentSalt_20260201_080450/cover
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_256/5_Random_Adaptive_ContentSalt_20260201_080450/stego
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_128/5_Random_Adaptive_ContentSalt_20260204_125926/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_128/5_Random_Adaptive_ContentSalt_20260204_125926/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_voc500_128" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_voc500_128" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001 \
  --runs 10
# Out:
# 2026-06-16 13:51:56.204170: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
#  BAT DAU TIEN TRINH HUAN LUYEN STEGANALYSIS
#  Thoi gian: 2026-06-16 13:51:59
# ...
#  Dữ liệu Cover: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_128/5_Random_Adaptive_ContentSalt_20260204_125926/cover
#  Dữ liệu Stego: /content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_128/5_Random_Adaptive_ContentSalt_20260204_125926/stego
#  Mô hình: CNN | Depth: 5 | Filters: 64 | BiLSTM: False
#  Hyperparams: Epochs=50 | Batch=32 | LR=0.0001
# ------------------------------------------------------------
#
# [Trainer] Starting experiment: Algo=CNN | LR=0.0001
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_128/5_Random_Adaptive_ContentSalt_20260204_125926/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_128/5_Random_Adaptive_ContentSalt_20260204_125926/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_voc500_128" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_voc500_128" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-02-04 10:13:39.669301: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770200019.688457    7661 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770200019.694551    7661 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770200019.709612    7661 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import os


num_runs = 7

cover_dir = ""
stego_dir = ""
cache_dir = "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_voc500_128"
base_log_dir = "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_voc500_128"

for i in range(1, num_runs + 1):

    command = (
        f'python train.py '
        f'--cover "{cover_dir}" '
        f'--stego "{stego_dir}" '
        f'--algo cnn '
        f'--cache_dir "{cache_dir}" '
        f'--log_dir "{base_log_dir}" '
        f'--depth 5 '
        f'--filters 64 '
        f'--epochs 50 '
        f'--lr 0.0001'
    )

    print(f"Running iteration {i}/{num_runs}")
    os.system(command)
# Out:
# Running iteration 1/7
# Running iteration 2/7
# Running iteration 3/7
# Running iteration 4/7
# Running iteration 5/7
# Running iteration 6/7
# Running iteration 7/7

# %%
import os


num_runs = 7

cover_dir = ""
stego_dir = ""
cache_dir = "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_voc500_256"
base_log_dir = "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_voc500_256"

for i in range(1, num_runs + 1):

    command = (
        f'python train.py '
        f'--cover "{cover_dir}" '
        f'--stego "{stego_dir}" '
        f'--algo cnn '
        f'--cache_dir "{cache_dir}" '
        f'--log_dir "{base_log_dir}" '
        f'--depth 5 '
        f'--filters 64 '
        f'--epochs 50 '
        f'--lr 0.0001'
    )

    print(f"Running iteration {i}/{num_runs}")
    os.system(command)
# Out:
# Running iteration 1/7
# Running iteration 2/7
# Running iteration 3/7
# Running iteration 4/7
# Running iteration 5/7
# Running iteration 6/7
# Running iteration 7/7

# %%
import os


num_runs = 7

cover_dir = ""
stego_dir = ""
cache_dir = "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_voc500_512"
base_log_dir = "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_voc500_512"

for i in range(1, num_runs + 1):

    command = (
        f'python train.py '
        f'--cover "{cover_dir}" '
        f'--stego "{stego_dir}" '
        f'--algo cnn '
        f'--cache_dir "{cache_dir}" '
        f'--log_dir "{base_log_dir}" '
        f'--depth 5 '
        f'--filters 64 '
        f'--epochs 50 '
        f'--lr 0.0001'
    )

    print(f"Running iteration {i}/{num_runs}")
    os.system(command)
# Out:
# Running iteration 1/7
# Running iteration 2/7
# Running iteration 3/7
# Running iteration 4/7
# Running iteration 5/7
# Running iteration 6/7
# Running iteration 7/7
