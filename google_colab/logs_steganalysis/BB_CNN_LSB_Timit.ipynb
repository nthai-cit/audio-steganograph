# %%
import os
import shutil
from google.colab import drive
# Kết nối lại (ép buộc)
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
PROJECT_PATH = '/content/drive/MyDrive/Git-audio-stego/audio-steganograph'
if os.path.exists(PROJECT_PATH):
    os.chdir(PROJECT_PATH)
    # !pip install -q librosa soundfile tensorflow scikit-learn seaborn
else:
    print(f" Không tìm thấy thư mục tại {PROJECT_PATH}")


print("\n có thể bắt đầu Train.")

import numpy as np
import os
# Out:
#  có thể bắt đầu Train.

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.1/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.1/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_0.1" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_0.1" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-01-31 02:56:49.466721: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769828209.486676   18200 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769828209.492774   18200 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769828209.508103   18200 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.2/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.2/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_0.2" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_0.2" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-01-31 03:02:11.897185: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769828531.917675   20405 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769828531.923820   20405 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769828531.939572   20405 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.3/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.3/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_0.3" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_0.3" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-01-31 03:07:40.447179: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769828860.466880   22629 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769828860.472912   22629 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769828860.487990   22629 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.4/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_0.4" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_0.4" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-01-31 03:13:06.107425: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769829186.127914   24841 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769829186.134213   24841 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769829186.150038   24841 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.5/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.5/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_0.5" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_0.5" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-01-31 08:47:09.771590: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769849229.791848   12819 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769849229.798116   12819 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769849229.814373   12819 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.065/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_1000_0.065/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_0.065" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_0.065" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-02-01 02:45:40.993869: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769913941.014748   24354 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769913941.020875   24354 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769913941.035841   24354 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_512/5_Random_Adaptive_ContentSalt_20260201_083210/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_512/5_Random_Adaptive_ContentSalt_20260201_083210/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_voc500_512" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_voc500_512" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-02-01 02:43:40.022978: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769913820.056161   22930 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769913820.066536   22930 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769913820.091328   22930 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py \
  --cover "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_256/5_Random_Adaptive_ContentSalt_20260201_080450/cover" \
  --stego "/content/drive/MyDrive/HK1-20252026/Steganography/Ablation/Timit_voc_500_256/5_Random_Adaptive_ContentSalt_20260201_080450/stego" \
  --algo cnn \
  --cache_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/Data/LSB_CNN_Case5_Timit1000_voc500_256" \
  --log_dir "/content/drive/MyDrive/Git-audio-stego/audio-steganograph/Steganalysis/logs/LSB_CNN_Case5_Timit1000_voc500_256" \
  --depth 5 \
  --filters 64 \
  --epochs 50 \
  --lr 0.0001
# Out:
# 2026-02-01 02:28:32.415985: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769912912.461641   17459 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769912912.475782   17459 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769912912.511896   17459 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
